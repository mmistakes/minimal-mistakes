# %% [markdown]
# The code cell below creates a `DataFrame` containing data on the population of a selection of countries in the years 2020 and 2010. This `DataFrame` will be used in the exercises below.
#
# **Important:** do not change the code below - otherwise the assignment will not be graded properly, which will likely prevent you from getting full marks.

# %%
import pandas as pd

data = {
    "country": ["Portugal", "China", "India", "United States","Poland", "Indonesia", "Greece"],
    "population (2020)": [10196709, 1439323776, 1380004385, 331002651, 37846611, 273523615, 10423054],
    "population (2010)": [10596058, 1368810615, 1234281170, 309011475, 38329781, 241834215, 10887637]
}


df = pd.DataFrame(data)
df

# %% [markdown]
# ### Exercise 1.1 (2 points)
#
# The code cell below creates a dictionary called `new_data` which contains additional data that should be added to `df`. Below is a preview of how `df` should look:
#
# ![ex_1.1.png](attachment:ex_1.1.png)
#
# In general, when completing these exercises, it is a good idea to preview `df` each time, in order to make sure that everything is correct.
#
# **Hint:** in order to make sure the index of the additional data is correct, you could, for example:
# 1. pass in the index manually
# 2. use the `ignore_index` argument of the `concat` method
# 3. use the `reset_index()` method of a `DataFrame`

# %%
new_data = {
    "country": ["Hungary", "Egypt"],
    "population (2020)": [9660351, 102334404],
    "population (2010)": [9927370, 82761235]
}

# %%
# the line of code below is to preview the dataframe
df

# %% [markdown]
# ### Exercise 1.2 (1 point)
#
# Create a new column in `df` called "change", which shows the change in the population between the year 2010 and 2020. Below is a **partial** preview of what `df` should look like:
#
# ![ex_1_2.png](attachment:ex_1_2.png)

# %% [markdown]
# ### Exercise 1.3 (2 points)
#
# Create a new column in `df` called "relative_change", which shows the relative change in population between the year 2010 and 2020. All of the values in that column should be rounded to **2 decimal places**. Below is a **partial** preview of what `df` should look like:
#
# ![ex_1_3.png](attachment:ex_1_3.png)
#
# **Hint:** you can use the `.round()` method in a `Series` object to round all of the values in a `Series` to some number of decimal places.

# %% [markdown]
# ### Exercise 1.4 (4 points)
#
# Create a new column in `df` called "status". If the population of a country has grown between 2010 and 2020 then the value in the column should be "growing". If the population has declined between 2010 and 2020, then the value should be "declining". Below is a **partial** preview of what `df` should look like:
#
# ![ex_1_4.png](attachment:ex_1_4.png)

# %% [markdown]
# ### Exercise 1.5 (1 point)
#
# Create a new `DataFrame` without the column "population (2020)" and assign it to the variable `df2`. Below is a **partial** preview of what `df2` should look like:
#
# ![ex_1_5.png](attachment:ex_1_5.png)
#
# **Hint:** you can use the `drop()` method with `df` and assign the returned `DataFrame` to variable `df2`.
